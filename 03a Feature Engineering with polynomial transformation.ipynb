# %%
import pandas as pd
import pickle

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, ElasticNet

import scipy.stats as stats
import statsmodels.api as sm

import seaborn as sns

# %%
# import new era data and creaste dummy variables
new_era = pickle.load(open('ready_for_model_new_era.p','rb'))
new_era['new_era'] = 1
# import old era data and create dummy variables
old_era = pickle.load(open('ready_for_model_old_era.p','rb'))
old_era['new_era'] = 0

# %%
combined_data = pd.concat([new_era,old_era])
combined_data['win_per'] = combined_data['win_per'] *100

# %%
combined_data = combined_data.drop('year', axis =1)

# %%
combined_data.columns
# Out:
# Index(['ORtg_p1', 'ORtg_p2', 'ORtg_p3', 'ORtg_p4', 'ORtg_p5', 'DRtg_p1',
#        'DRtg_p2', 'DRtg_p3', 'DRtg_p4', 'DRtg_p5', 'win_per', 'new_era'],
#       dtype='object')

# %%
X , y = combined_data.drop('win_per',axis =1), combined_data['win_per']

# %%
X['intercept'] = 1

# %%
# Create your model
model = sm.OLS(y, X)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                win_per   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     314.7
# Date:                Thu, 18 Apr 2019   Prob (F-statistic):          3.20e-231
# Time:                        17:55:04   Log-Likelihood:                -1829.4
# No. Observations:                 571   AIC:                             3683.
# Df Residuals:                     559   BIC:                             3735.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ORtg_p1        0.3573      0.066      5.418      0.000       0.228       0.487
# ...

# %%
combined_data['ORtg_p1_era'] = combined_data['ORtg_p1'] * combined_data['new_era']
combined_data['ORtg_p2_era'] = combined_data['ORtg_p2'] * combined_data['new_era']
combined_data['ORtg_p3_era'] = combined_data['ORtg_p3'] * combined_data['new_era']
combined_data['ORtg_p4_era'] = combined_data['ORtg_p4'] * combined_data['new_era']
combined_data['ORtg_p5_era'] = combined_data['ORtg_p5'] * combined_data['new_era']

combined_data['DRtg_p1_era'] = combined_data['DRtg_p1'] * combined_data['new_era']
combined_data['DRtg_p2_era'] = combined_data['DRtg_p2'] * combined_data['new_era']
combined_data['DRtg_p3_era'] = combined_data['DRtg_p3'] * combined_data['new_era']
combined_data['DRtg_p4_era'] = combined_data['DRtg_p4'] * combined_data['new_era']
combined_data['DRtg_p5_era'] = combined_data['DRtg_p5'] * combined_data['new_era']

# %%
combined_data.drop('new_era',axis = 1, inplace =True)

# %%
combined_data.columns
# Out:
# Index(['ORtg_p1', 'ORtg_p2', 'ORtg_p3', 'ORtg_p4', 'ORtg_p5', 'DRtg_p1',
#        'DRtg_p2', 'DRtg_p3', 'DRtg_p4', 'DRtg_p5', 'win_per', 'ORtg_p1_era',
#        'ORtg_p2_era', 'ORtg_p3_era', 'ORtg_p4_era', 'ORtg_p5_era',
#        'DRtg_p1_era', 'DRtg_p2_era', 'DRtg_p3_era', 'DRtg_p4_era',
#        'DRtg_p5_era'],
#       dtype='object')

# %%
X , y = combined_data.drop('win_per',axis =1), combined_data['win_per']

# %%
X['intercept'] = 1

# %%
# # Polynomial Transformation
# poly = PolynomialFeatures(degree = 2)
# X_poly = poly.fit_transform(X)
# X_poly_columns = poly.get_feature_names(X.columns)

# %%
# # print column names in order
# X_poly_columns

# %%
# Scale X features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
pickle.dump(X_scaled, open('features_to_plot.p','wb'))

# %%
pickle.dump(y, open('target.p','wb'))

# %%
pd.DataFrame(X_scaled)['intercept'] = 1

# %%
# Create your model
model = sm.OLS(y, X)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                win_per   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     175.7
# Date:                Thu, 18 Apr 2019   Prob (F-statistic):          1.13e-223
# Time:                        17:55:05   Log-Likelihood:                -1821.8
# No. Observations:                 571   AIC:                             3686.
# Df Residuals:                     550   BIC:                             3777.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ORtg_p1         0.2218      0.112      1.976      0.049       0.001       0.442
# ...

# %%
# Create your model
model = sm.OLS(y, X_scaled)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1633: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/statsmodels/base/model.py:1106: RuntimeWarning: invalid value encountered in absolute
#   return stats.t.sf(np.abs(self.tvalues), df_resid) * 2
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
# ...

# %%
X = pickle.load(open('features_to_plot.p','rb'))
y = pickle.load(open('target.p','rb'))

# %%
# Create your model
model = sm.OLS(y, X)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                win_per   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.389
# Date:                Thu, 18 Apr 2019   Prob (F-statistic):           0.000674
# Time:                        17:55:05   Log-Likelihood:                -3049.3
# No. Observations:                 571   AIC:                             6139.
# Df Residuals:                     551   BIC:                             6226.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.3033      5.657      0.230      0.818      -9.808      12.415
# ...
