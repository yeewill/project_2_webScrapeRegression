# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re

# %%
chromedriver = "~/Downloads/chromedriver" # path to the chromedriver executable
chromedriver = os.path.expanduser(chromedriver)
print('chromedriver path: {}'.format(chromedriver))
sys.path.append(chromedriver)
driver = webdriver.Chrome(chromedriver)
# Out:
# chromedriver path: /Users/williamyee/Downloads/chromedriver

# %%
zillow_pleasanton_url = "https://www.zillow.com/homes/recently_sold/Pleasanton-CA/house_type/47164_rid/globalrelevanceex_sort/37.739092,-121.750317,37.583086,-122.028408_rect/11_zm/"
driver.get(zillow_pleasanton_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
listings = soup.find_all("a", class_="zsg-photo-card-overlay-link")
listings
# Out:
# []

# %%
listings
# Out:
# []

# %%
# Out:
# <!DOCTYPE html>
# <html class="zsg-theme-modernized null fonts-stage-1 fonts-stage-2 yui3-js-enabled" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/product#"><head><style type="text/css">.gm-control-active&gt;img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active&gt;img:nth-child(1){display:block}.gm-control-active:hover&gt;img:nth-child(1),.gm-control-active:active&gt;img:nth-child(1){display:none}.gm-control-active:hover&gt;img:nth-child(2),.gm-control-active:active&gt;img:nth-child(3){display:block}
# </style><link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Google+Sans" rel="stylesheet" type="text/css"/><style type="text/css">.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# </style><style type="text/css">.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# </style><style type="text/css">@media print {  .gm-style .gmnoprint, .gmnoprint {    display:none  }}@media screen {  .gm-style .gmnoscreen, .gmnoscreen {    display:none  }}</style><style type="text/css">.gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}
# </style>
# <meta content="on" http-equiv="x-dns-prefetch-control"/><link href="//www.zillowstatic.com" rel="dns-prefetch"/><link href="//fonts.googleapis.com" rel="dns-prefetch"/><link href="//photos.zillowstatic.com" rel="dns-prefetch"/><link crossorigin="true" href="https://www.zillow.com/graphql/" rel="preconnect"/><link crossorigin="true" href="https://mortgageapi.zillow.com" rel="preconnect"/><meta charset="utf-8"/><title>Recently Sold Homes in Pleasanton CA - 2,254 Transactions | Zillow</title><meta content="Browse data on the 2,254 recent real estate transactions in Pleasanton CA. Great for discovering comps, sales history, photos, and more." name="description"/><meta content="Zillow, Inc." name="author"/><meta content="Copyright (c) 2006-2019 Zillow, Inc." name="Copyright"/><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="//bat.bing.com/bat.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="/HYx10rg3/init.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-P6HT97"></script><script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2019040101.js"></script><script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-WQL55SH&amp;cid=316384179.1554764972" type="text/javascript"></script><script async="true" src="https://sb.scorecardresearch.com/beacon.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script id="google-1-tap" src="https://smartlock.google.com/client"></script><script async="" src="https://analytics.zg-api.com/a/z/js/v1/analytics.js"></script><script>var UI_INIT_AT = Date.now ? Date.now() : +(new Date());</script><link href="https://www.zillowstatic.com/static-zsg/d2386fd/static-zsg/zsg/zsg-core.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/static-zsg/d2386fd/static-zsg/zsg/zsg-opt.css" media="all" rel="stylesheet" type="text/css"/><script>
#         /* Font Face Observer v2.1.0 - © Bram Stein. License: BSD-3-Clause */(function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&amp;&amp;f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&amp;&amp;b.then;if(null!=b&amp;&amp;"object"==typeof b&amp;&amp;"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}
#     function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&amp;&amp;("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};
#     function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&amp;&amp;b(h)}}var e=0,h=[];0==a.length&amp;&amp;b(h);
#     for(var k=0;a.length &gt; k;
#     k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;
#     a.length &gt; d;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());
#
#     (function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function t(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";
#     this.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}
#     function u(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+b+";"}function z(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function A(a,b){function c(){var a=k;z(a)&amp;&amp;a.a.parentNode&amp;&amp;b(a.g)}var k=a;l(a.b,c);l(a.c,c);z(a)};function B(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var C=null,D=null,E=null,F=null;function G(){if(null===D)if(J()&amp;&amp;/Apple/.test(window.navigator.vendor)){var a=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))(?:\.([0-9]+))/.exec(window.navigator.userAgent);D=!!a&amp;&amp;603&gt;parseInt(a[1],10)}else D=!1;return D}function J(){null===F&amp;&amp;(F=!!document.fonts);return F}
#     function K(){if(null===E){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}E=""!==a.style.font}return E}function L(a,b){return[a.style,a.weight,K()?a.stretch:"","100px",b].join(" ")}
#     B.prototype.load=function(a,b){var c=this,k=a||"BESbswy",r=0,n=b||3E3,H=(new Date).getTime();return new Promise(function(a,b){if(J()&amp;&amp;!G()){var M=new Promise(function(a,b){function e(){(new Date).getTime()-H&gt;=n?b(Error(""+n+"ms timeout exceeded")):document.fonts.load(L(c,'"'+c.family+'"'),k).then(function(c){1&lt;=c.length?a():setTimeout(e,25)},b)}e()}),N=new Promise(function(a,c){r=setTimeout(function(){c(Error(""+n+"ms timeout exceeded"))},n)});Promise.race([N,M]).then(function(){clearTimeout(r);a(c)},
#     b)}else m(function(){function v(){var b;if(b=-1!=f&amp;&amp;-1!=g||-1!=f&amp;&amp;-1!=h||-1!=g&amp;&amp;-1!=h)(b=f!=g&amp;&amp;f!=h&amp;&amp;g!=h)||(null===C&amp;&amp;(b=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),C=!!b&amp;&amp;(536&gt;parseInt(b[1],10)||536===parseInt(b[1],10)&amp;&amp;11&gt;=parseInt(b[2],10))),b=C&amp;&amp;(f==w&amp;&amp;g==w&amp;&amp;h==w||f==x&amp;&amp;g==x&amp;&amp;h==x||f==y&amp;&amp;g==y&amp;&amp;h==y)),b=!b;b&amp;&amp;(d.parentNode&amp;&amp;d.parentNode.removeChild(d),clearTimeout(r),a(c))}function I(){if((new Date).getTime()-H&gt;=n)d.parentNode&amp;&amp;d.parentNode.removeChild(d),b(Error(""+
#     n+"ms timeout exceeded"));else{var a=document.hidden;if(!0===a||void 0===a)f=e.a.offsetWidth,g=p.a.offsetWidth,h=q.a.offsetWidth,v();r=setTimeout(I,50)}}var e=new t(k),p=new t(k),q=new t(k),f=-1,g=-1,h=-1,w=-1,x=-1,y=-1,d=document.createElement("div");d.dir="ltr";u(e,L(c,"sans-serif"));u(p,L(c,"serif"));u(q,L(c,"monospace"));d.appendChild(e.a);d.appendChild(p.a);d.appendChild(q.a);document.body.appendChild(d);w=e.a.offsetWidth;x=p.a.offsetWidth;y=q.a.offsetWidth;I();A(e,function(a){f=a;v()});u(e,
#     L(c,'"'+c.family+'",sans-serif'));A(p,function(a){g=a;v()});u(p,L(c,'"'+c.family+'",serif'));A(q,function(a){h=a;v()});u(q,L(c,'"'+c.family+'",monospace'))})})};"object"===typeof module?module.exports=B:(window.FontFaceObserver=B,window.FontFaceObserver.prototype.load=B.prototype.load);}());
#     </script><link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet"/><style>@font-face{font-family:Ivar Headline;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff2) format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff) format("woff");font-weight:600;font-style:normal;font-display:swap;unicode-range:u+0000-001f,u+0080-200f,u+2020-faff,u+fb10-ffff}@font-face{font-family:Ivar Headline;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff2) format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff) format("woff");font-weight:600;font-style:normal;font-display:swap;unicode-range:u+0020-007f,u+201?,u+fb0?}@font-face{font-family:Ivar Headline Subset;src:url("data:application/x-font-woff2;charset=utf-8;base64,...") format("woff2");font-weight:600;font-style:normal;unicode-range:u+0020,u+0041-005a,u+0061-007a}</style><script>(function(){var o="v1";var s="fontsVersion";var r=" fonts-stage-1";var l=" fonts-stage-2";if(sessionStorage[s]===o||typeof Promise==="undefined"){document.documentElement.className+=l;return}var e=new FontFaceObserver("Ivar Headline Subset");e.load().then(function(){document.documentElement.className+=r;var e=new FontFaceObserver("Ivar Headline",{weight:600});var n=new FontFaceObserver("Open Sans");var a=new FontFaceObserver("Open Sans",{weight:600});var t=new FontFaceObserver("Open Sans",{weight:700});return Promise.all([e.load(null,1e4),n.load(null,1e4),a.load(null,1e4),t.load(null,1e4)]).then(function(){document.documentElement.className+=l;sessionStorage[s]=o})}).catch(function(){document.documentElement.className+=l})})();</script><link href="https://www.zillowstatic.com/cdp/587012e/dist/ds-community-details/css/community-details-366ab1896d.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/cdp/587012e/dist/community-details/css/community-details-be2432d697.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/hdp/fced36a/home-details/css/home-details-af5233845e.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.zillowstatic.com/s/?static.9fccb87=css/z-modules/header.css,css/z-modules/ui-action-bar.css&amp;static-topnav.50c3b55=css/z-modules/sub-nav-wide.css&amp;static-modals.4cdd552=css/mobile-dialog.css&amp;static-pagewrapper.fc76d74=css/z-modules/header-wide.css" media="all" rel="stylesheet" type="text/css"/><link href="https://s.zillowstatic.com/static-search-page/6f5f8e8/search-app/css/search-page-687fd2261c.css" media="all" rel="stylesheet" type="text/css"/><meta content="none" name="msapplication-config"/><meta content="NOINDEX, FOLLOW" name="ROBOTS"/><meta content="NOYDIR" name="ROBOTS"/><meta content="NOODP" name="ROBOTS"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/><meta content="telephone=no" name="format-detection"/><link href="https://www.zillowstatic.com/static/images/m/apple-touch-icon.png" rel="apple-touch-icon"/><meta content="#3366b8" name="msapplication-TileColor"/><meta content="https://www.zillowstatic.com/static/images/logos/zillow-logo-win8-tile.png" name="msapplication-TileImage"/><meta content="/8Me6HBNZX/rt2n5/y1Lo3ZIrkcvkTBimqviTDiurR4=" name="verify-v1"/><meta content="7cb4abe457d82ae8" name="y_key"/><link href="https://www.zillow.com/pleasanton-ca/sold/house_type/" rel="canonical"/><meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/><meta content="Zillow Real Estate, Rentals, and Mortgage" itemprop="name"/><meta content="The most trafficked website about home sales and rentals, with real estate values for almo ...
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# </script><script>if(typeof ZILLOW==="undefined"){var ZILLOW={}}(function(w,d){if(top!=self){top.location.replace(self.location.href)}var h=d.getElementsByTagName("html")[0];h.className=h.className.replace(/(?:^|\s)no-js(?!\S)/g,"");var l=w.location,a=l.hash,sn,snr=/scrnnm=[^&amp;\}]+/;if(a&amp;&amp;a.indexOf("scrnnm")&gt;0&amp;&amp;(sn=a.match(snr)[0])){a=l.hash.replace(snr,"");a=a.replace(/&amp;&amp;/,"&amp;").replace(/\{&amp;/,"{").replace(/&amp;\}/,"}").replace(/\{\}/,"");w.location=l.protocol+"//"+l.host+l.pathname+(l.search?l.search+"&amp;"+sn:"?"+sn)+a}ZILLOW.facebookSdkUrl="//connect.facebook.net/en_US/all.js";
# /*@cc_on
#             var q=d.createElement('div');q.innerHTML='&lt;z&gt;i&lt;/z&gt;';q.childNodes.length!==1&amp;&amp;('abbr article aside audio canvas details figcaption '+
#             'figure footer header hgroup mark meter nav output progress section summary time video').replace(/\w+/g,function(n){d.createElement(n)});
#             @*/
# })(this,document);var oldErr=window.onerror;window.cpErrors=0;window.onerror=function(f,c,b){try{cpErrors++;if(window.zonLog){var a="c=uncaught&amp;m="+encodeURI(f)+"&amp;u="+encodeURI(c)+"&amp;l="+encodeURI(b)+"&amp;r="+encodeURI(document.referrer);window.zonLog("Unhandled Error: "+a)}if(console&amp;&amp;console.error){console.error("Unhandled error found. "+f+" "+c+" "+b+" "+document.referrer)}if(oldErr){return oldErr(f,c,b)}return false}catch(d){if(console&amp;&amp;console.error){console.error("Couldn't process error.",d)}}};if(document.addEventListener){document.addEventListener("DOMContentLoaded",function ProfileDOMContentLoadedEvent(a){ClientProfiler.profile("DOMContentLoaded");setTimeout(function(){if(ga&amp;&amp;performance&amp;&amp;typeof performance.getEntriesByName==="function"&amp;&amp;performance.getEntriesByName("DOMContentLoaded").length&gt;0){ga("set","dimension72",parseFloat(performance.getEntriesByName("DOMContentLoaded")[0].startTime.toString()).toFixed(2))}},2000);document.removeEventListener("DOMContentLoaded",ProfileDOMContentLoadedEvent)})}if(window.addEventListener){window.addEventListener("load",function ProfileLoadEvent(a){ClientProfiler.profile("native browser onload");setTimeout(function(){if(ga&amp;&amp;performance&amp;&amp;typeof performance.getEntriesByName==="function"&amp;&amp;performance.getEntriesByName("native browser onload").length&gt;0){ga("set","dimension73",parseFloat(performance.getEntriesByName("native browser onload")[0].startTime.toString()).toFixed(2))}},2000);window.removeEventListener("load",ProfileLoadEvent)})}ZILLOW.PROFILER_ACTIVE=true;var _gaq=_gaq||[],_gaqBackup=_gaqBackup||[];</script><script>if(typeof ClientProfiler!=="undefined"){ClientProfiler.profile("css finished")};</script><link href="https://www.zillowstatic.com/static-zsg/d2386fd/static-zsg/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/><script>
#         (function(z,c,m){m=z[c]={};m.queue=[];m.add=function(a){m.queue.push(a)}})(window,'ZCM');
#     </script><script async="" src="//www.googletagservices.com/tag/js/gpt.js"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/common.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/util.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/map.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/overlay.js" type="text/javascript"></script><script async="" charset="utf-8" src="https://www.zillowstatic.com/l/?wants=intl,event-base,event-custom-base,node-base,yui-later,z-filter,z-mobile-react-combined-view,z-mobile-react-list-view,z-mobile-search-results,z-mobile-show-commute,zillow-node-methods&amp;deploy=admin-account-tools.c1a3188,adtech-landing.null,adv.2ef0d63,advice.25e5aad,agentteams.db3e983,app-upsell.60aca8f,app-views.e7c3391,async-content.36c5773,bdp.416cb6f,best-time.c479a30,bpro.3cf9b7b,building-admin.a38dad3,chinese-landing-page.8ee294a,claim.a2ad0b8,community-pillar.cedeb1e,complaints.73682e1,contact-form.ab43ef7,contacts.55f0ac7,email-a-friend.847f564,ecui.43a4038,formatters.34b921e,gtm.c9391e2,hdp.65e88ce,hdp-legacy-shim.257c863,homepage.3727afe,homevalues.0222034,inspections.8ed1066,instant-offer.null,keystone.013621e,lazy-image-loader.3d4bf58,managed-lifecycle.e29d665,map.2037907,mobile-landingpage.2bfadf9,modals.4cdd552,npm.d369a91,santas-house.9b25f76,nc-map.8b727d1,neighborhood.89348a6,pa.a17d2a7,pagewrapper.fc76d74,paparazzi.0a7c207,permits.0ea0805,personalization.b9899d2,posting-path.8fbf7ba,pricing-tool.d22743d,profile.18ee6de,property-maps.af51401,property-photos.a79d59e,rent-affordability.a556e8a,renterprofile.bd46dac,rentvsbuy.6dc0b2d,richdata.7ffa87b,sales-history.90c0fd2,schools.88c5bb5,search.91f2f1c,searchbar.12c3c54,seller.99cb128,seller-landing.a07313d,seopages.2ab1829,smart-banner.594889c,social-media-tools.dcd85c8,third-party-ads.ec54100,topnav.50c3b55,user-account.4faeb77,validation-regexes.b3d0b3a,vcr.57e2860,video-landing.ba70953,webview-support.c3a282d,widgets.8b54f70,yui.5b7360e,zsg.d2386fd,static.9fccb87&amp;afterFn=_womboResponse" type="text/javascript"></script><style type="text/css">@keyframes zsgLoaderSpin{0%{transform:rotate(0deg)}to{transform:rotate(1turn)}}.act-auth-container .user-account{margin:0 auto;width:100%}@media screen and (max-width:480px){.act-auth-container .user-account{max-width:100%}}.act-auth-container .user-account .module-forgot-password,.act-auth-container .user-account .module-redirect,.act-auth-container .user-account .module-terms-of-use{padding:8px}.act-auth-container .user-account .module-footer{text-align:center}.act-auth-container .user-account .zsg-form-field{position:relative}.act-auth-container .user-account input{height:38px}.act-auth-container .user-account input[type=submit]{width:100%}.act-auth-container .user-account .continue,.act-auth-container .user-account .extension,.act-auth-container .user-account .module-separator{text-align:center}.act-auth-container .user-account .continue a,.act-auth-container .user-account .continue label,.act-auth-container .user-account .extension a,.act-auth-container .user-account .extension label,.act-auth-container .user-account .module-separator a,.act-auth-container .user-account .module-separator label{line-height:38px}.act-auth-container .user-account .phone-label{padding:0 0 0 10px;line-height:38px}.act-auth-container .user-account.passwordless-auth{width:auto;max-width:520px}@media only screen and (max-width:520px){.act-auth-container .user-account.passwordless-auth{max-width:100%}}.act-auth-container .user-account.streamlined-agent{width:560px}.act-auth-container .user-account.streamlined-agent .module-wrap{padding:20px;box-shadow:0 1px 2px #ccc;box-shadow:0 1px 2px rgba(0,0,0,.3)}.act-auth-container .user-account.sem-lightbox .module-right{padding:20px;border:1px so ...
#         font: 400 11px Roboto, Arial, sans-serif;
#         text-decoration: none;
#       }
#       .gm-style img { max-width: none; }</style><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/onion.js" type="text/javascript"></script><script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/35/10a/stats.js" type="text/javascript"></script><style class="autocomplete-list-sam-skin" type="text/css">/*
# YUI 3.18.1 (build f7e7bcb)
# Copyright 2014 Yahoo! Inc. All rights reserved.
# Licensed under the BSD License.
# http://yuilibrary.com/license/
# */
#
# .yui3-aclist{position:absolute;z-index:1}.yui3-aclist-hidden{visibility:hidden}.yui3-aclist-aria{left:-9999px;position:absolute}.yui3-aclist-list{list-style:none;margin:0;overflow:hidden;padding:0}.yui3-aclist-item{cursor:pointer;list-style:none;padding:2px 5px}.yui3-aclist-item-active{outline:#afafaf dotted thin}.yui3-skin-sam .yui3-aclist-content{background:#fff;border:1px solid #afafaf;-moz-box-shadow:1px 1px 4px rgba(0,0,0,0.58);-webkit-box-shadow:1px 1px 4px rgba(0,0,0,0.58);box-shadow:1px 1px 4px rgba(0,0,0,0.58)}.yui3-skin-sam .yui3-aclist-item-hover{background:#bfdaff}.yui3-skin-sam .yui3-aclist-item-active{background:#2647a0;color:#fff;outline:0}#yui3-css-stamp.skin-sam-autocomplete-list{display:none}
# </style><script async="" charset="utf-8" src="https://www.zillowstatic.com/l/?wants=keystone-event-source,z-save-home-reg-dialup_ACT-616&amp;deploy=admin-account-tools.c1a3188,adtech-landing.null,adv.2ef0d63,advice.25e5aad,agentteams.db3e983,app-upsell.60aca8f,app-views.e7c3391,async-content.36c5773,bdp.416cb6f,best-time.c479a30,bpro.3cf9b7b,building-admin.a38dad3,chinese-landing-page.8ee294a,claim.a2ad0b8,community-pillar.cedeb1e,complaints.73682e1,contact-form.ab43ef7,contacts.55f0ac7,email-a-friend.847f564,ecui.43a4038,formatters.34b921e,gtm.c9391e2,hdp.65e88ce,hdp-legacy-shim.257c863,homepage.3727afe,homevalues.0222034,inspections.8ed1066,instant-offer.null,keystone.013621e,lazy-image-loader.3d4bf58,managed-lifecycle.e29d665,map.2037907,mobile-landingpage.2bfadf9,modals.4cdd552,npm.d369a91,santas-house.9b25f76,nc-map.8b727d1,neighborhood.89348a6,pa.a17d2a7,pagewrapper.fc76d74,paparazzi.0a7c207,permits.0ea0805,personalization.b9899d2,posting-path.8fbf7ba,pricing-tool.d22743d,profile.18ee6de,property-maps.af51401,property-photos.a79d59e,rent-affordability.a556e8a,renterprofile.bd46dac,rentvsbuy.6dc0b2d,richdata.7ffa87b,sales-history.90c0fd2,schools.88c5bb5,search.91f2f1c,searchbar.12c3c54,seller.99cb128,seller-landing.a07313d,seopages.2ab1829,smart-banner.594889c,social-media-tools.dcd85c8,third-party-ads.ec54100,topnav.50c3b55,user-account.4faeb77,validation-regexes.b3d0b3a,vcr.57e2860,video-landing.ba70953,webview-support.c3a282d,widgets.8b54f70,yui.5b7360e,zsg.d2386fd,static.9fccb87&amp;have=50523936a475ad81855945370294573adf14270d&amp;afterFn=_womboResponse" type="text/javascript"></script><script charset="utf-8" id="yui_3_18_1_1_1554764970105_87" src="https://www.zillowstatic.com/static-user-actions/LIVE/save-home-handler/app-1dc51a506f.js"></script><script charset="utf-8" id="yui_3_18_1_1_1554764970105_109" src="https://www.zillowstatic.com/hdp/fced36a/overall-commons-566cd7220d.js"></script><script async="" charset="utf-8" id="yui_3_18_1_1_1554764970105_192" src="https://consent.truste.com/notice?domain=zillow.com&amp;c=teconsent&amp;text=true"></script><script charset="utf-8" id="yui_3_18_1_1_1554764970105_110" src="https://www.zillowstatic.com/hdp/fced36a/home-details/ssr/app-891c535c35.js"></script><script charset="utf-8" id="yui_3_18_1_1_1554764970105_115" src="https://www.zillowstatic.com/cdp/587012e/dist/overall-commons-53448fe71a.js"></script><script charset="utf-8" id="yui_3_18_1_1_1554764970105_116" src="https://www.zillowstatic.com/cdp/587012e/dist/server/app-517a91f9f0.js"></script><script async="" charset="utf-8" src="https://www.zillowstatic.com/l/?wants=z-keystone-event-cache&amp;deploy=admin-account-tools.c1a3188,adtech-landing.null,adv.2ef0d63,advice.25e5aad,agentteams.db3e983,app-upsell.60aca8f,app-views.e7c3391,async-content.36c5773,bdp.416cb6f,best-time.c479a30,bpro.3cf9b7b,building-admin.a38dad3,chinese-landing-page.8ee294a,claim.a2ad0b8,community-pillar.cedeb1e,complaints.73682e1,contact-form.ab43ef7,contacts.55f0ac7,email-a-friend.847f564,ecui.43a4038,formatters.34b921e,gtm.c9391e2,hdp.65e88ce,hdp-legacy-shim.257c863,homepage.3727afe,homevalues.0222034,inspections.8ed1066,instant-offer.null,keystone.013621e,lazy-image-loader.3d4bf58,managed-lifecycle.e29d665,map.2037907,mobile-landingpage.2bfadf9,modals.4cdd552,npm.d369a91,santas-house.9b25f76,nc-map.8b727d1,neighborhood.89348a6,pa.a17d2a7,pagewrapper.fc76d74,paparazzi.0a7c207,permits.0ea0805,personalization.b9899d2,posting-path.8fbf7ba,pricing-tool.d22743d,profile.18ee6de,property-maps.af51401,property-photos.a79d59e,rent-affordability.a556e8a,renterprofile.bd46dac,rentvsbuy.6dc0b2d,richdata.7ffa87b,sales-history.90c0fd2,schools.88c5bb5,search.91f2f1c,searchbar.12c3c54,seller.99cb128,seller-landing.a07313d,seopages.2ab1829,smart-banner.594889c,social-media-tools.dcd85c8,third-party-ads.ec54100,topnav.50c3b55,user-account.4faeb77,validation-regexes.b3d0b3a,vcr.57e2860,video-landing.ba70953,webview-support.c3a282d,widgets.8b54f70,yui.5b7360e,zsg.d ...
# <body class="actionbar-inline srp-page-container nav-full-width zsg-layout_full responsive-search-page hide-top-nav-gleam bdp-double-scroll-layout tengage wide znav-search-bar">
# <script>new Image().src = 'https://www.zillow.com/ui/JavascriptEnabled.htm?guid=92743119b6c1487d9169c85477262a8b&amp;zPage=Search%3ARealEstateSearch%3AList&amp;hostId=qIi8aKMyyQ4&amp;time=' + Date.now();</script><svg style="display:none" xmlns="http://www.w3.org/2000/svg"><symbol id="logo-text-svg" viewbox="0 0 100 100"><path d="M61.2 81.8c1.1-1.2 1.5-2.6 1.5-4.7c0-2-0.4-3.3-1.4-4.5c-1.1-1.2-2.4-1.8-4.2-1.8c-3.3 0-5.5 2.6-5.5 6.4 c0 3.9 2.2 6.4 5.5 6.4C59 83.5 60.3 82.9 61.2 81.8z M58.6 73.7c0.4 0.6 0.7 1.6 0.7 3.3c0 2.9-0.6 4.1-2 4.1c-0.6 0-1.3-0.3-1.6-1 c-0.3-0.6-0.4-1.7-0.4-3.1c0-1.2 0.1-2.1 0.3-2.7c0.3-0.8 0.9-1.2 1.7-1.2C57.8 73.1 58.3 73.3 58.6 73.7z M76.8 83.2L80.4 71H77 l-0.9 4.4c-0.3 1.6-0.6 3.5-0.7 4c0 0-0.4-2.1-0.9-4.3l-1-4.1h-3l-1.2 4.1c-0.6 2.1-0.9 4.3-0.9 4.3S68 77 67.7 75.5l-1-4.6h-3.3 l3.4 12.3h3l0.6-2.5c0.3-1.1 0.8-3.3 1.1-4.3c0.2-0.9 0.2-1.1 0.3-1.6c0.1 0.5 0.1 0.6 0.2 1.2c0.1 0.8 0.4 2 0.7 3l1.1 4.2H76.8z M45.8 83.2h3.3l0-17.7l-3.3 0.7L45.8 83.2z M39.4 83.2h3.3l0-17.7l-3.3 0.7L39.4 83.2z M33 83.3h3.2l0-11.5L33 72.5L33 83.3z M34.6 71c1.1 0 2-0.9 2-2c0-1.1-0.9-2-2-2c-1.1 0-2 0.9-2 2C32.7 70.2 33.6 71 34.6 71z M30 83.2l0.9-2.7h-5.6l-1.4 0 c0 0 0.3-0.5 0.6-1.1l6.4-11.1v-2.4h-10L20 68.7h5.2c1 0 1.4 0 1.4 0s-0.2 0.6-0.7 1.4l-6.3 10.8v2.3H30z"></path></symbol><symbol id="logo-house-svg" viewbox="0 0 100 100"><path d="M30 48.8c4.9-5.1 22.6-21.5 22.6-21.5c-9.2 2.2-18.8 5.1-22.3 6.7l-5.2 5.3c4.3-0.9 5.7-1.1 8.9-1.6L30 48.8z M62.8 23.2c0 0-15.6 15.8-18.1 18c4.8-1.7 14.5-3.8 20.7-4.1c0.7-2.2 1.5-3.8 1.5-3.8l8.3-0.8C75.2 32.5 68.9 27.4 62.8 23.2z M27.3 56.3c1.8-0.8 18.6-6.4 34.1-7.3c0.3-1.3 2-5.7 2.3-6.9c-16.1 1.1-29.1 6-34.4 8.4L27.3 56.3z M52.4 16.3 c-2.8 1.3-10.8 7.5-15.1 10.7c5.2-1.8 17.8-4.6 24.3-4.7C59.6 20.9 53.9 17.1 52.4 16.3z"></path></symbol></svg><script>if(typeof ClientProfiler!=="undefined"){ClientProfiler.profile("html body started")};</script><a id="top" name="top"></a><noscript>&lt;iframe width="0" style="display:none;visibility:hidden" src="//www.googletagmanager.com/ns.html?id=GTM-P6HT97" height="0"&gt;&lt;/iframe&gt;</noscript><div class="main-wrapper" id="wrapper"><div class="zsg-modal-mask"></div>
# <div id="pfs-nav-wrapper"><div data-reactroot=""><style>.znav,.znav-mask,.znav-masked{width:100%;height:100%}
# .svg-fill{fill:#006aff;stroke:#006aff}
# .svg-accent,.znav-transparent header:not(.znav-mobile-open) .svg-fill{fill:#fff;stroke:#fff}
# .znav-masked{position:fixed;overflow:hidden!important}
# .znav-mask{display:none;position:fixed;z-index:1;background:#fff;opacity:.8}
# .znav,.znav-logo-mobile,.znav-nav{position:relative}
# .znav-mobile-open .znav-mask{display:block}
# .znav{z-index:1000;background-color:#fff;font:'Gotham Book',Gotham-Book,Arial,sans-serif}
# .spoof dt,.znav-dropdown-expanded&gt;a,.znav-links-anonymous li a,.znav-links-home-link a{font-weight:700}
# .znav-nav{height:100%;z-index:2;border-bottom:1px solid #ccc}
# .znav-logo{height:50px;display:-ms-flexbox;display:flex;-ms-flex-align:center;align-items:center;-ms-flex-pack:start;justify-content:flex-start;padding:0 15px;z-index:2}
# .znav-topnav-logo{margin:12px auto auto;height:30px}
# .znav-logo-full{height:25px;-ms-flex-order:2;order:2;width:94px;margin:auto;opacity:1}
# .znav-logo-hamburger{-ms-flex-order:0;order:0}
# .znav-menu-mobile-svg{height:33px;width:25px}
# .znav-mobile-open .znav-menu-mobile-svg{display:none}
# .znav-logo-mobile{display:inline-block;height:25px}
# .znav .notification{display:inline-block;color:#fff;background-color:#e96e2f;min-width:34px;line-height:20px;height:22px;margin:auto auto auto 5px;border-radius:12px;text-align:center;padding:1px 4px 0;font-size:14px;-ms-flex:0 0 auto;flex:0 0 auto}
# .znav .zsg-icon-expando-down,.znav .zsg-icon-expando-up{-ms-flex:0 0 40px;flex:0 0 40px;padding:0 25px;display:-ms-flexbox;display:flex;-ms-flex-align:center;align-items:center;color:#006aff}
# .znav-links{display:none;position:fixed;height:100%;z-index:2;overflow:scroll;-ms-flex-direction:column;flex-direction:column;width:100%;background:#fff;margin-top:1px}
# .znav-mobile-open .znav-links{display:-ms-flexbox;display:flex}
# .znav-links&gt;ul&gt;li{min-height:53px;display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;flex-wrap:wrap}
# .znav-links-home-link{display:block;color:#0074e4;position:absolute;top:28px;left:15px;z-index:3}
# .znav-links-home-link a:visited{color:#006aff}
# .znav-links-help{display:none}
# .znav-links-user{-ms-flex-order:-1;order:-1;margin-top:78px;border-top:1px solid #d8d8d8}
# .znav-links-user .znav-link-text{white-space:nowrap;text-overflow:ellipsis}
# .znav-links-anonymous{display:-ms-flexbox;display:flex;-ms-flex-pack:end;justify-content:flex-end;-ms-flex-order:-1;order:-1;min-height:78px;border-bottom:1px solid #d8d8d8}
# .znav-links-main .znav-section-title .notification,.znav-links-marketing .znav-section-title .notification,.znav-links-marketing&gt;li:not(:first-child),.znav-links-user .znav-section-title .notification{display:none}
# .znav-links-anonymous li{-ms-flex-align:center;align-items:center}
# .znav-links-anonymous li a{color:#006aff}
# .znav-links-anonymous li:nth-child(2){margin-right:15px}
# .znav-links-anonymous li:nth-child(2):before{padding:0 5px;color:#2a2a33;content:'or'}
# .znav-links-marketing li{border-bottom:none}
# .znav-links-marketing li span{color:#006aff;font-weight:700}
# .znav-links-marketing li:nth-child(even){-ms-flex-order:1;order:1}
# .znav-links-marketing li:nth-child(odd){-ms-flex-order:2;order:2}
# .znav-links-main&gt;li,.znav-links-user&gt;li{border-bottom:1px solid #d8d8d8}
# .znav-links-main .znav-section-title,.znav-links-user .znav-section-title{border-right:1px solid #d8d8d8}
# .znav-links-main .znav-dropdown a:visited,.znav-links-user .znav-dropdown a:visited{color:#006aff!important}
# .znav-links-main .znav-section-title,.znav-links-marketing .znav-section-title,.znav-links-user .znav-section-title{margin:12px 0 13px 15px;font-size:15px;color:#2a2a33;-ms-flex:1 0 50%;flex:1 0 50%;line-height:28px}
# .znav-dropdown{display:none;-ms-flex:1 0 auto;flex:1 0 auto;border-top:1px solid #d8d8d8}
# .znav-dropdown-expanded .znav-dropdown{display:block}
# .znav-dropdown .znav-link-text{display:-ms-flexbox;display:flex;-ms-flex-direction:row;flex-direction:row;width:100%}
# .znav-dropdown .znav-link-text span:not(.notification){overflow:hidden;-ms-flex:1 1 auto;flex:1 1 auto;text-overflow:ellipsis}
# .znav-dropdown-expanded&gt;div{width:100%}
# .znav-dropdown-expanded a.znav-section-title{color:#006aff}
# .znav-dropdown-content{background:#fafafa;padding:0 30px}
# .znav-dropdown-sections{padding-bottom:20px}
# .znav-dropdown-sections&gt;li{padding-top:20px}
# .znav-dropdown-header{-ms-flex:1 0 100%;flex:1 0 100%;font-size:15px;color:#2a2a33;margin:0;line-height:40px}
# .znav-dropdown-links li{line-height:40px}
# .znav-admin .znav-section-title{color:#c00}
# .znav-admin .znav-section-title span{margin-right:5px}
# .znav-transparent header:not(.znav-mobile-open){background-color:rgba(0,0,0,0)}
# .znav-transparent header:not(.znav-mobile-open) .svg-accent{fill-opacity:0;stroke-opacity:0}
# .znav-transparent header:not(.znav-mobile-open) .znav-nav{border:0}
# .znav-transparent header:not(.znav-mobile-open) .hamburger-inner,.znav-transparent header:not(.znav-mobile-open) .hamburger-inner::after,.znav-transparent header:not(.znav-mobile-open) .hamburger-inner::before{background:#fff}
# .znav-search-bar:not(.hdp-double-scroll-layout) .znav:not(.znav-mobile-open) .hamburger{position:static}
# .znav-search-bar:not(.hdp-double-scroll-layout) .znav:not(.znav-mobile-open) .znav-topnav-logo{display:inline-block;margin-left:4px}
# .znav-search-bar:not(.hdp-double-scroll-layout) .znav:not(.znav-mobile-open) .znav-logo-full{opacity:0}
# @media all and (min-width:769px){.znav-links{max-width:375px;border-right:1px solid #ccc}
# }
# .hamburger{padding:2px 0 0;display:inline-block;cursor:pointer;position:absolute;transition-property:opacity,filter;transition-duration:.15s;transition-timing-function:linear;background-color:transparent}
# .hamburger-box{width:24px;height:24px;display:inline-block;position:relative}
# .hamburger-inner{display:block;top:50%}
# .hamburger-inner,.hamburger-inner::after,.hamburger-inner::before{width:18px;height:2px;background-color:#006aff;border-radius:4px;position:absolute;transition-property:transform;transition-duration:.15s;transition-timing-function:ease}
# .hamburger-inner::after,.hamburger-inner::before{content:'';display:block}
# .hamburger-inner{transition-duration:75ms;transition-timing-function:cubic-bezier(.55,.055,.675,.19)}
# .hamburger-inner::before{top:-6px;transition:top 75ms .12s ease,opacity 75ms ease}
# .hamburger-inner::after{bottom:-6px;transition:bottom 75ms .12s ease,transform 75ms cubic-bezier(.55,.055,.675,.19)}
# .znav-mobile-open .hamburger-inner{transform:rotate(45deg);transition-delay:.12s;transition-timing-function:cubic-bezier(.215,.61,.355,1)}
# .znav-mobile-open .hamburger-inner::before{top:0;opacity:0;transition:top 75ms ease,opacity 75ms .12s ease}
# .znav-mobile-open .hamburger-inner::after{bottom:0;transform:rotate(-90deg);transition:bottom 75ms ease,transform 75ms .12s cubic-bezier(.215,.61,.355,1)}
# .spoof{width:100%;text-align:left;border-bottom:2px dashed red;background-color:#fff}
# .spoof dd,.spoof dt{display:inline-block;padding:4px}
# .spoof dt{color:red}
# .spoof a{text-decoration:none} .search-page #wrapper.main-wrapper{padding-top:0}
# .search-page #wrapper .property-data-column{top:100px}
# .search-page .zsg-searchbox .yui3-aclist{left:10px!important}
# body{padding-top:0!important}
# @media all and (min-width:769px){.search-page #search-anchor.zsg-nav-sub{padding-left:0!important}
# .search-page .zsg-nav-sub-wrapper{margin-top:0}
# .search-page #wrapper #c-column.property-data-column{top:130px}
# body.responsive-search-page .search-page-wide-header{margin-left:0;margin-top:0;width:100%;position:relative}
# body.responsive-search-page:not(.mobile-web) #wrapper div[data-zrr-key="static-search-page:search-app"]{height:calc(100% - 80px)}
# body.responsive-search-page .search-page-tablet-header{margin-left:15px;margin-top:-32px;width:100%}
# body.responsive-search-page .search-page-tablet-header .wow-exposed-filters:not(.pinned) .react-exposed-filters-action-bar{margin-left:-230px;width:auto}
# body.responsive-search-page .search-page-tablet-header .wow-exposed-filter .filter-button-popover{right:auto}
# body.responsive-search-page .wow-exposed-filters.pinned{top:15px}
# }
# @media all and (max-width:768px){.mobile-search-page .dismiss-region-control,.mobile-search-page .draw-search-control{bottom:50px}
# .search-form-wrapper .searchbar-top{left:75px;padding-top:8px;width:calc(100% - 90px)}
# .znav-masked .search-form-wrapper .searchbar-top{display:none}
# }
# #search-back-link.zss-header,body:not(.hdp-double-scroll-layout) #home-details-render #mobile-back-link{background:#fff}
# .hdp-classic-layout #content #mobile-back-link{display:none}
# @media all and (screen and (min-width:769px) and (max-width:1024px)){body.responsive-search-page:not(.mobile-web) div[data-zrr-key="static-search-page:search-app"]{padding-top:0}
# }
# body.responsive-search-page .search-page-header-container{max-width:100%}
# .znav .search-page-header-container{left:81px;top:8px}
# @media all and (min-width:768px){div.zsg-nav-sub-wrapper{margin-top:0}
# body:not(.mobile-web) div.zsg-nav-sub-wrapper{margin-top:0!important}
# }
# body:not(.nav-full-width) div.zsg-nav-sub-wrapper .zsg-nav-sub{padding-left:4px}
# body.znav-force-mobile-layout .ds-nav-bar .znav-mobile-open .znav-links{max-height:100vh;height:calc(100vh - 50px)}
# body.mobile-search-page.mobile-web .app-upsell-wrapper{position:fixed} @media all and (min-width:769px){body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-anonymous li a,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing li span{color:#2a2a33;font-weight:400}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav{height:80px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-nav{border-bottom:1px solid #d8d8d8;position:static}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo{position:absolute;left:56%;height:80px;transform:translate(-50%,0);border:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-topnav-logo{height:36px;margin-top:24px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).znav-search-bar .znav-logo .znav-logo-full{opacity:1}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo-full{height:32px;width:120px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo-mobile{height:32px;width:32px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo-full,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo-mobile,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-topnav-logo{transition:left .15s ease-out,height .15s ease-out,width .15s ease-out,margin-top .15s ease-out}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav .zsg-icon-expando-down,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav .zsg-icon-expando-up,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-logo-hamburger{display:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links{display:-ms-flexbox;display:flex;-ms-flex-pack:justify;justify-content:space-between;-ms-flex-direction:row;flex-direction:row;position:static;width:100%;max-width:1280px;margin:auto;border:none;padding-right:24px;z-index:1;overflow:visible}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links&gt;ul&gt;li{display:inline-block;line-height:80px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-home-link{display:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user{-ms-flex-order:0;order:0;margin:0;border:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li.znav-admin ul.znav-dropdown-sections&gt;li{-ms-flex-preferred-size:100%;flex-basis:100%}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li.znav-admin div.znav-dropdown{right:auto;min-width:400px;margin-left:-330px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li:hover .znav-dropdown{display:-ms-flexbox;display:flex}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown{max-width:400px;min-width:300px;right:40px;max-height:80vh;border:1px solid #d8d8d8;overflow:auto}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-sections{overflow:auto;display:block;-ms-flex-direction:column;flex-direction:column;width:100%;padding:0}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-sections&gt;li{border-bottom:1px solid #d8d8d8;margin:0;padding:20px 28px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-sections&gt;li:last-child{-ms-flex-preferred-size:100%;flex-basis:100%}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-content{padding:0;min-width:298px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-columns{overflow:hidden}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li .znav-dropdown-columns li{width:100%}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown{left:0;width:100%}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-sections{padding-bottom:0}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-sections&gt;li:first-child{margin-left:0;border-left:none;padding-left:0}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-sections&gt;li{margin:25px 28px 24px 0;padding-top:0;padding-left:28px;border-left:1px solid #d8d8d8}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user{margin-left:24px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main&gt;li:hover .znav-dropdown,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li:hover .znav-dropdown{visibility:visible;opacity:1;transition:opacity .1s,visibility .1s;transition-delay:.4s}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown{position:absolute;display:-ms-flexbox;display:flex;visibility:hidden;opacity:0;transition:opacity 0s,visibility 0s;transition-delay:.5s;top:80px;margin-top:-1px;background-color:#fff;border-bottom:1px solid #d8d8d8}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-sections,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown-sections{display:-ms-flexbox;display:flex}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-content,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown-content{display:-ms-flexbox;display:flex;max-width:1280px;margin:auto;padding:0 24px;width:100%;background-color:#fff}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-columns,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown-columns{display:-ms-flexbox;display:flex}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-columns&gt;li:first-child,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown-columns&gt;li:first-child{margin-left:0}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-dropdown-columns&gt;li,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-dropdown-columns&gt;li{margin-left:20px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-anonymous{-ms-flex-order:0;order:0;border:none;margin-right:13px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing{margin-left:auto}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing li:not(:first-child){display:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user{display:-ms-flexbox;display:flex}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main&gt;li,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing&gt;li,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user&gt;li{border:none}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-section-title,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing .znav-section-title,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-section-title{border:none;margin:auto;padding-right:16px;font-size:14px}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-main .znav-section-title .notification,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-marketing .znav-section-title .notification,body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout) .znav-links-user .znav-section-title .notification{display:inline-block}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).znav-transparent .znav-nav{background-color:#fff}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).znav-transparent header .znav-logo .svg-fill{fill:#006aff;stroke:#006aff}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).znav-transparent header .znav-logo .svg-accent{fill-opacity:1;stroke-opacity:1}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).znav-transparent header .znav-logo .znav-logo{border:2px solid #2a2a33}
# body:not(.mobile-web):not(.tablet-web):not(.znav-force-mobile-layout).nav-full-width .znav-links{max-width:100%}
# ...
# var _comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/homes/recently_sold/Pleasanton-CA/house_type/47164_rid/globalrelevanceex_sort/37.739092,-121.750317,37.583086,-122.028408_rect/11_zm/",c5:"",c6:"",c15:""});var _comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);
#
# // --&gt;</script>
# <iframe id="google_osd_static_frame_7852818044487" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe>
# <script id="" type="text/javascript">function setCookie(name,value,expires){var url=google_tag_manager["GTM-P6HT97"].macro(6);var cookie=name+"\x3d"+value+"; path\x3d/; domain\x3d."+url.replace(/^www\./i,"");if(typeof expires!=="undefined"){var now=new Date;now.setTime(now.getTime()+expires*365*24*60*60*1E3);cookie+="; expires\x3d"+now.toUTCString()}document.cookie=cookie}var fbc;if(google_tag_manager["GTM-P6HT97"].macro(7)){fbc="fb.1."+Date.now()+".undefined";setCookie("fbc","fb.1."+Date.now()+".undefined",10)}var imgPixel=document.createElement("img");
# var src="https://www.facebook.com/tr/?id\x3d547145892064117\x26ev\x3dPageView\x26zscript\x3d1\x26dl\x3dhttps://www.zillow.com/";if(google_tag_manager["GTM-P6HT97"].macro(8)||fbc){fbc=fbc||google_tag_manager["GTM-P6HT97"].macro(9);src+="\x26fbc\x3d"+fbc}imgPixel.setAttribute("height",1);imgPixel.setAttribute("width",1);imgPixel.setAttribute("border",0);imgPixel.setAttribute("alt","");imgPixel.setAttribute("style","display:none");imgPixel.setAttribute("referrerpolicy","no-referrer");
# if("gtm.js"==="gtm.historyChange")src+="\x26cd[content_id]\x3dundefined";imgPixel.setAttribute("src",src);document.body.appendChild(imgPixel);</script><img alt="" border="0" height="1" referrerpolicy="no-referrer" src="https://www.facebook.com/tr/?id=547145892064117&amp;ev=PageView&amp;zscript=1&amp;dl=https://www.zillow.com/" style="display:none" width="1"/>
# <noscript>&lt;img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=547145892064117&amp;amp;ev=PageView&amp;amp;noscript=1"&gt;</noscript>
# <script id="" type="text/javascript">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"4017789"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&amp;&amp;"loaded"!==b&amp;&amp;"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><script id="" type="text/javascript">function EchoGA(){"undefined"!=typeof ga&amp;&amp;null!=ga&amp;&amp;ga(function(c){ga_echo={};try{for(var a=0;a&lt;c.b.data.keys.length;a++)ga_echo[c.b.data.keys[a]]=c.get(c.b.data.keys[a])}catch(b){console.log("GA Echo \x3e "+b.message)}})}EchoGA();
# "undefined"!=typeof ga&amp;&amp;null!=ga&amp;&amp;ga(function(c){c.send=function(a,b,d,e,f,g){if(0&lt;=document.location.href.indexOf("gtmdbg")||"undefined"!=typeof gtmdbg)debugger;c.__proto__.send.call(c,a,b,d,e,f,g);try{EchoGA(),"object"==typeof a?(ga_echo.eventCategory=String(a.eventCategory),ga_echo.eventAction="undefined"!=typeof a.eventAction?String(a.eventAction):"",ga_echo.eventLabel="undefined"!=typeof a.eventLabel?String(a.eventLabel):"",dataLayer.push({event:String(ga_echo.eventCategory)+"#"+String(ga_echo.eventAction)+
# "#"+String(ga_echo.eventLabel)})):"object"==typeof b?(ga_echo.eventCategory=String(b.eventCategory),ga_echo.eventAction="undefined"!=typeof b.eventAction?String(b.eventAction):"",ga_echo.eventLabel="undefined"!=typeof b.eventLabel?String(b.eventLabel):"",dataLayer.push({event:String(ga_echo.eventCategory)+"#"+String(ga_echo.eventAction)+"#"+String(ga_echo.eventLabel)})):"pageview"!=a&amp;&amp;(ga_echo.eventCategory=String(b.eventCategory),ga_echo.eventAction="undefined"!=typeof d.eventAction?String(d.eventAction):
# "",ga_echo.eventLabel="undefined"!=typeof e.eventLabel?String(e.eventLabel):"",dataLayer.push({event:String(ga_echo.eventCategory)+"#"+String(ga_echo.eventAction)+"#"+String(ga_echo.eventLabel)}))}catch(h){console.log("GA Echo \x3e "+h.message)}}});</script>
# <script id="" type="text/javascript">function OptanonWrapper(){window.dataLayer.push({event:"OneTrustGroupsUpdated"})};</script>
# <iframe height="0" src="//4704202.fls.doubleclick.net/activityi;src=4704202;type=unive0;cat=zillo0;ord=1306669541641;gtm=2wg3r3;auiddc=1418599347.1554764978;u3=undefined;u2=undefined;u1=undefined;u5=92743119b6c1487d9169c85477262a8b;u4=316384179.1554764972;u6=undefined;u7=undefined;u8=undefined;u9=undefined;u10=undefined;u11=undefined;u12=undefined;u13=undefined;u14=CA;u15=undefined;~oref=https%3A%2F%2Fwww.zillow.com%2Fhomes%2Frecently_sold%2FPleasanton-CA%2Fhouse_type%2F47164_rid%2Fglobalrelevanceex_sort%2F37.739092%2C-121.750317%2C37.583086%2C-122.028408_rect%2F11_zm%2F?" style="display: none; visibility: hidden;" width="0"></iframe><iframe height="0" src="//4704202.fls.doubleclick.net/activityi;src=4704202;type=searc0;cat=searc0;ord=8078856196480;gtm=2wg3r3;auiddc=1418599347.1554764978;u3=undefined;u2=undefined;u1=undefined;u5=92743119b6c1487d9169c85477262a8b;u4=316384179.1554764972;u6=undefined;u7=undefined;u8=undefined;u9=undefined;u10=undefined;u11=undefined;u12=undefined;u13=undefined;u14=CA;u15=undefined;~oref=https%3A%2F%2Fwww.zillow.com%2Fhomes%2Frecently_sold%2FPleasanton-CA%2Fhouse_type%2F47164_rid%2Fglobalrelevanceex_sort%2F37.739092%2C-121.750317%2C37.583086%2C-122.028408_rect%2F11_zm%2F?" style="display: none; visibility: hidden;" width="0"></iframe><script id="" type="text/javascript">var seoLandingTime=window.localStorage&amp;&amp;parseInt(window.localStorage.getItem("seoLandingTime"));if(seoLandingTime){var timeElapsed=(new Date).getTime()-seoLandingTime;32E3&gt;=timeElapsed?setTimeout(function(){window.localStorage.getItem("seoLandingTime")&amp;&amp;"undefined"!==typeof ga&amp;&amp;(window.localStorage.removeItem("seoLandingTime"),ga("send",{hitType:"event",eventCategory:"GC-EVENT",eventAction:"32 seconds"}))},32E3-timeElapsed):window.localStorage.removeItem("seoLandingTime")};</script><script id="" type="text/javascript">var imgPixel=document.createElement("img"),src="https://www.facebook.com/tr/?id\x3d547145892064117\x26ev\x3dSearch\x26zscript\x3d1\x26dl\x3dhttps://www.zillow.com/";google_tag_manager["GTM-P6HT97"].macro(10)&amp;&amp;(src+="\x26fbc\x3dundefined");imgPixel.setAttribute("height",1);imgPixel.setAttribute("width",1);imgPixel.setAttribute("border",0);imgPixel.setAttribute("alt","");imgPixel.setAttribute("style","display:none");imgPixel.setAttribute("referrerpolicy","no-referrer");src+="\x26cd[content_type]\x3dproduct\x26cd[content_ids]\x3d92743119b6c1487d9169c85477262a8b\x26cd[PageType]\x3dSearch\x26cd[ZipCode]\x3dundefined\x26cd[Neighborhood]\x3dundefined";
# imgPixel.setAttribute("src",src);document.body.appendChild(imgPixel);</script><img alt="" border="0" height="1" referrerpolicy="no-referrer" src="https://www.facebook.com/tr/?id=547145892064117&amp;ev=Search&amp;zscript=1&amp;dl=https://www.zillow.com/&amp;cd[content_type]=product&amp;cd[content_ids]=92743119b6c1487d9169c85477262a8b&amp;cd[PageType]=Search&amp;cd[ZipCode]=undefined&amp;cd[Neighborhood]=undefined" style="display:none" width="1"/><script id="" type="text/javascript">function setCookie(b,a,c){var d=google_tag_manager["GTM-P6HT97"].macro(11);b=b+"\x3d"+a+"; path\x3d/; domain\x3d."+d.replace(/^www\./i,"");"undefined"!==typeof c&amp;&amp;(a=new Date,a.setTime(a.getTime()+864E5*c),b+="; expires\x3d"+a.toUTCString());document.cookie=b}setCookie("KruxPixel","true",3);</script>
# <img alt="" height="1" src="https://beacon.krxd.net/usermatch.gif?partner=zillow&amp;partner_uid=92743119b6c1487d9169c85477262a8b" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="//usermatch.krxd.net/um/v2?partner=google" style="border-style:none;" width="1"/>
# <script id="" type="text/javascript">!function(c,d,g,e,a,f,b){c.ktag||(a=function(){a.sendEvent?a.sendEvent(arguments):a.ktq.push(arguments)},a.ktq=[],c.ktag=a,f=d.getElementsByTagName(e)[0],b=d.createElement(e),b.async=!0,b.src=g,f.parentNode.appendChild(b))}(window,document,"//resources.xg4ken.com/js/v2/ktag.js?tid\x3dKT-N3AF0-40D","script");ktag("setup","KT-N3AF0-40D","\x3cUSER_ID\x3e");</script>
# <noscript>
# 	&lt;img src="https://events.xg4ken.com/pixel/v2?tid=KT-N3AF0-40D&amp;amp;noscript=1" width="1" height="1" style="display:none"&gt;
# </noscript><iframe height="0" src="//4704202.fls.doubleclick.net/activityi;src=4704202;type=web;cat=visit;ord=undefined;gtm=Gaf;auiddc=93770161.1539842571;u1=undefined;u2=undefined;u3=Search;u4=316384179.1554764972;u5=92743119b6c1487d9169c85477262a8b;u6=undefined;u7=undefined;u8=undefined;u9=undefined;u10=undefined;u11=undefined;u12=undefined;u13=undefined;u14=CA;u15=undefined;~oref=https://www.zillow.com/homes/recently_sold/Pleasanton-CA/house_type/47164_rid/globalrelevanceex_sort/37.739092,-121.750317,37.583086,-122.028408_rect/11_zm/" style="display: none; visibility: hidden;" width="0"></iframe>
# <script id="" type="text/javascript">function setCookie(b,c){var a=google_tag_manager["GTM-P6HT97"].macro(12);a=b+"\x3d"+c+"; path\x3d/; domain\x3d."+a.replace(/^www\./i,"");document.cookie=a}setCookie("DoubleClickSession","true");</script><img alt="" src="https://pt.ispot.tv/v2/TC-2215-1.gif?type=universal_view" style="border:0"/><div id="batBeacon0.8070839502451903" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.34574320790276514" src="https://bat.bing.com/action/0?ti=4017789&amp;Ver=2&amp;mid=43a06a87-7f74-58f8-d902-06848454ab7f&amp;pi=1200101525&amp;lg=en-US&amp;sw=1680&amp;sh=1050&amp;sc=24&amp;tl=Recently%20Sold%20Homes%20in%20Pleasanton%20CA%20-%202,254%20Transactions%20%7C%20Zillow&amp;p=https%3A%2F%2Fwww.zillow.com%2Fhomes%2Frecently_sold%2FPleasanton-CA%2Fhouse_type%2F47164_rid%2Fglobalrelevanceex_sort%2F37.739092%2C-121.750317%2C37.583086%2C-122.028408_rect%2F11_zm%2F&amp;r=&amp;lt=4822&amp;evt=pageLoad&amp;msclkid=N&amp;rn=86276" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div><div id="batBeacon0.203094924964081" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.08466286192612582" src="https://bat.bing.com/action/0?ti=5527014&amp;Ver=2&amp;mid=81a06008-ce34-5ce2-2ace-44d22c62a9c6&amp;pi=1200101525&amp;lg=en-US&amp;sw=1680&amp;sh=1050&amp;sc=24&amp;tl=Recently%20Sold%20Homes%20in%20Pleasanton%20CA%20-%202,254%20Transactions%20%7C%20Zillow&amp;p=https%3A%2F%2Fwww.zillow.com%2Fhomes%2Frecently_sold%2FPleasanton-CA%2Fhouse_type%2F47164_rid%2Fglobalrelevanceex_sort%2F37.739092%2C-121.750317%2C37.583086%2C-122.028408_rect%2F11_zm%2F&amp;r=&amp;lt=4822&amp;evt=pageLoad&amp;msclkid=N&amp;rn=223214" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div><script id="" type="text/javascript">function setCookie(b,a,c){var d=google_tag_manager["GTM-P6HT97"].macro(14);b=b+"\x3d"+a+"; path\x3d/; domain\x3d."+d.replace(/^www\./i,"");"undefined"!==typeof c&amp;&amp;(a=new Date,a.setTime(a.getTime()+864E5*c),b+="; expires\x3d"+a.toUTCString());document.cookie=b}setCookie("KruxAddition","true",3);</script>
# <img alt="" height="1" src="https://usermatch.krxd.net/um/v2?partner=liveramp" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="//match.adsrvr.org/track/cmf/generic?ttd_pid=krux&amp;ttd_tpi=1" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="https://pixel.mathtag.com/sync/img?redir=https:%2F%2Fbeacon.krxd.net%2Fusermatch.gif%3Fpartner%3Dmediamath%26mmuuid%3D%5BMM_UUID%5D" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="https://usermatch.krxd.net/um/v2?partner=adobe" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="//usermatch.krxd.net/um/v2?partner=adnxs" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="//usermatch.krxd.net/um/v2?partner=exponential" style="border-style:none;" width="1"/>
# <img alt="" height="1" src="https://usermatch.krxd.net/um/v2?partner=triplelift" style="border-style:none;" width="1"/>
# </body></html><!-- H:040  T:123ms  S:367571  R:Mon Apr 08 16:09:28 PDT 2019  B:5.0.59614.5-hotfix_2019-04-03.e960f65~hotfix-platform-for-2019-04-03.368a366 -->
