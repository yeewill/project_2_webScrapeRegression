# %%
import pandas as pd
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
new_per_posses = pickle.load(open('current_nba_per_poss_data.p','rb'))

# %%
new_per_posses[1]
# Out:
#     Rk          Unnamed: 1  Age   G  GS    MP    FG   FGA    FG%   3P  ...  \
# 0    1        Jayson Tatum   20  79  79  2455   9.1  20.3  0.450  2.3  ...
# 1    2        Kyrie Irving   26  67  67  2214  13.1  27.0  0.487  3.8  ...
# 2    3        Marcus Smart   24  80  60  2200   5.2  12.4  0.422  2.8  ...
# 3    4       Marcus Morris   29  75  53  2091   8.7  19.4  0.447  3.4  ...
# 4    5          Al Horford   32  68  68  1973   9.4  17.7  0.535  1.8  ...
# 5    6        Jaylen Brown   22  74  25  1913   9.3  19.9  0.465  2.4  ...
# 6    7      Gordon Hayward   28  72  18  1863   7.7  16.4  0.466  2.0  ...
# 7    8        Terry Rozier   24  79  14  1791   6.9  17.9  0.387  3.2  ...
# 8    9        Daniel Theis   26  66   2   908   7.7  14.1  0.549  1.4  ...
# 9   10         Aron Baynes   32  51  18   821   6.2  13.1  0.471  1.2  ...
# 10  11        Semi Ojeleye   24  56   3   594   5.4  12.8  0.424  2.3  ...
# 11  12      Brad Wanamaker   29  36   0   343   7.0  14.7  0.476  2.2  ...
# 12  13     Robert Williams   21  32   2   283   6.1   8.7  0.706  0.0  ...
# 13  14  Guerschon Yabusele   23  41   1   251   6.7  14.8  0.455  1.7  ...
# 14  15           PJ Dozier   22   6   0    51   7.6  19.8  0.381  1.9  ...
# 15  16         R.J. Hunter   25   1   0    26  11.1  24.1  0.462  7.4  ...
# 16  17         Greg Monroe   28   2   0     5  28.9  48.2  0.600  0.0  ...
#
#     TOV   PF   PTS  Unnamed: 27  ORtg  DRtg  year  wins  losses  \
# 0   2.4  3.3  24.4          NaN   107   107  2019    49      33
# 1   3.7  3.6  34.7          NaN   118   108  2019    49      33
# 2   2.7  4.4  15.5          NaN   113   107  2019    49      33
# 3   2.1  4.2  24.1          NaN   110   109  2019    49      33
# 4   2.5  3.1  22.6          NaN   122   107  2019    49      33
# 5   2.5  4.7  24.3          NaN   104   109  2019    49      33
# 6   2.7  2.7  21.3          NaN   114   109  2019    49      33
# 7   1.8  2.7  19.0          NaN   106   108  2019    49      33
# 8   1.8  8.5  19.8          NaN   128   107  2019    49      33
# 9   2.3  7.3  16.7          NaN   118   108  2019    49      33
# 10  1.5  3.5  15.1          NaN   106   112  2019    49      33
# 11  2.7  4.8  19.7          NaN   118   110  2019    49      33
# 12  1.7  6.1  13.8          NaN   132   100  2019    49      33
# 13  2.9  6.1  18.0          NaN   108   109  2019    49      33
# 14  0.0  1.9  17.9          NaN   112   107  2019    49      33
# 15  0.0  5.6  31.5          NaN   131   111  2019    49      33
# 16  0.0  0.0  57.8          NaN   142   118  2019    49      33
#
#     win_percentages
# 0          0.597561
# 1          0.597561
# 2          0.597561
# 3          0.597561
# 4          0.597561
# 5          0.597561
# 6          0.597561
# 7          0.597561
# 8          0.597561
# 9          0.597561
# 10         0.597561
# 11         0.597561
# 12         0.597561
# 13         0.597561
# 14         0.597561
# 15         0.597561
# 16         0.597561
#
# [17 rows x 34 columns]

# %%
ORtg_p1 = []
ORtg_p2 = []
ORtg_p3 = []
ORtg_p4 = []
ORtg_p5 = []
DRtg_p1 = []
DRtg_p2 = []
DRtg_p3 = []
DRtg_p4 = []
DRtg_p5 = []
win_per = []
year = []
for new_per_poss in new_per_posses:
    team_year= new_per_poss[:5].sort_values(by ='ORtg',ascending =False).reset_index()

    ORtg_p1.append(team_year.iloc[0,-6])
    ORtg_p2.append(team_year.iloc[1,-6])
    ORtg_p3.append(team_year.iloc[2,-6])
    ORtg_p4.append(team_year.iloc[3,-6])
    ORtg_p5.append(team_year.iloc[4,-6])

    team_year= new_per_poss[:5].sort_values(by ='DRtg',ascending =False).reset_index()

    DRtg_p1.append(team_year.iloc[0,-5])
    DRtg_p2.append(team_year.iloc[1,-5])
    DRtg_p3.append(team_year.iloc[2,-5])
    DRtg_p4.append(team_year.iloc[3,-5])
    DRtg_p5.append(team_year.iloc[4,-5])
    
    win_per.append(team_year.iloc[0,-1])
    year.append(team_year.iloc[0,-4])

# %%
team_year_new_per_poss = pd.DataFrame(
    {
    'ORtg_p1':ORtg_p1,
    'ORtg_p2':ORtg_p2,
    'ORtg_p3':ORtg_p3,
    'ORtg_p4':ORtg_p4,
    'ORtg_p5':ORtg_p5,
    'DRtg_p1':DRtg_p1,
    'DRtg_p2':DRtg_p2,
    'DRtg_p3':DRtg_p3,
    'DRtg_p4':DRtg_p4,
    'DRtg_p5':DRtg_p5,
    'win_per':win_per,
    'year':year
    }
)

# %%
pickle.dump(team_year_new_per_poss,open('ready_for_model_new_era.p','wb'))

# %%
old_per_posses = pickle.load(open('Old_nba_per_poss_data.p','rb'))

# %%
ORtg_p1 = []
ORtg_p2 = []
ORtg_p3 = []
ORtg_p4 = []
ORtg_p5 = []
DRtg_p1 = []
DRtg_p2 = []
DRtg_p3 = []
DRtg_p4 = []
DRtg_p5 = []
win_per = []
year=[]
for old_per_poss in old_per_posses:
    team_year= old_per_poss[:5].sort_values(by ='ORtg',ascending =False).reset_index()

    ORtg_p1.append(team_year.iloc[0,-6])
    ORtg_p2.append(team_year.iloc[1,-6])
    ORtg_p3.append(team_year.iloc[2,-6])
    ORtg_p4.append(team_year.iloc[3,-6])
    ORtg_p5.append(team_year.iloc[4,-6])

    team_year= old_per_poss[:5].sort_values(by ='DRtg',ascending =False).reset_index()

    DRtg_p1.append(team_year.iloc[0,-5])
    DRtg_p2.append(team_year.iloc[1,-5])
    DRtg_p3.append(team_year.iloc[2,-5])
    DRtg_p4.append(team_year.iloc[3,-5])
    DRtg_p5.append(team_year.iloc[4,-5])
    
    win_per.append(team_year.iloc[0,-1])
    year.append(team_year.iloc[0,-4])

# %%
team_year_old_per_poss = pd.DataFrame(
    {
    'ORtg_p1':ORtg_p1,
    'ORtg_p2':ORtg_p2,
    'ORtg_p3':ORtg_p3,
    'ORtg_p4':ORtg_p4,
    'ORtg_p5':ORtg_p5,
    'DRtg_p1':DRtg_p1,
    'DRtg_p2':DRtg_p2,
    'DRtg_p3':DRtg_p3,
    'DRtg_p4':DRtg_p4,
    'DRtg_p5':DRtg_p5,
    'win_per':win_per,
    'year':year
    }
)

# %%
pickle.dump(team_year_old_per_poss,open('ready_for_model_old_era.p','wb'))

# %%
combined_data = pd.concat([team_year_new_per_poss, team_year_old_per_poss])

# %%
sns.pairplot(combined_data.drop('year',axis=1));

# %%
combined_data_ORtg_p1 = combined_data[['ORtg_p1','win_per','year']]
combined_data_ORtg_p2 = combined_data[['ORtg_p2','win_per','year']]
combined_data_ORtg_p3 = combined_data[['ORtg_p3','win_per','year']]
combined_data_ORtg_p4 = combined_data[['ORtg_p4','win_per','year']]
combined_data_ORtg_p5 = combined_data[['ORtg_p5','win_per','year']]

combined_data_DRtg_p1 = combined_data[['DRtg_p1','win_per','year']]
combined_data_DRtg_p2 = combined_data[['DRtg_p2','win_per','year']]
combined_data_DRtg_p3 = combined_data[['DRtg_p3','win_per','year']]
combined_data_DRtg_p4 = combined_data[['DRtg_p4','win_per','year']]
combined_data_DRtg_p5 = combined_data[['DRtg_p5','win_per','year']]

combined_data_ORtg_p1['value'] = 'ORtg_p1'
combined_data_ORtg_p2['value'] = 'ORtg_p2'
combined_data_ORtg_p3['value'] = 'ORtg_p3'
combined_data_ORtg_p4['value'] = 'ORtg_p4'
combined_data_ORtg_p5['value'] = 'ORtg_p5'

combined_data_DRtg_p1['value'] = 'DRtg_p1'
combined_data_DRtg_p2['value'] = 'DRtg_p2'
combined_data_DRtg_p3['value'] = 'DRtg_p3'
combined_data_DRtg_p4['value'] = 'DRtg_p4'
combined_data_DRtg_p5['value'] = 'DRtg_p5'

combined_data_ORtg_p1.rename(columns = {'ORtg_p1': 'rating'}, inplace = True)
combined_data_ORtg_p2.rename(columns = {'ORtg_p2': 'rating'}, inplace = True)
combined_data_ORtg_p3.rename(columns = {'ORtg_p3': 'rating'}, inplace = True)
combined_data_ORtg_p4.rename(columns = {'ORtg_p4': 'rating'}, inplace = True)
combined_data_ORtg_p5.rename(columns = {'ORtg_p5': 'rating'}, inplace = True)

combined_data_DRtg_p1.rename(columns = {'DRtg_p1': 'rating'}, inplace = True)
combined_data_DRtg_p2.rename(columns = {'DRtg_p2': 'rating'}, inplace = True)
combined_data_DRtg_p3.rename(columns = {'DRtg_p3': 'rating'}, inplace = True)
combined_data_DRtg_p4.rename(columns = {'DRtg_p4': 'rating'}, inplace = True)
combined_data_DRtg_p5.rename(columns = {'DRtg_p5': 'rating'}, inplace = True)
# Out:
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/williamyee/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
combined_data_violin_plot = pd.concat([
    combined_data_ORtg_p1,
    combined_data_ORtg_p2,
    combined_data_ORtg_p3,
    combined_data_ORtg_p4,
    combined_data_ORtg_p5,
    combined_data_DRtg_p1,
    combined_data_DRtg_p2,
    combined_data_DRtg_p3,
    combined_data_DRtg_p4,
    combined_data_DRtg_p5, 
])

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
violin_plot = sns.violinplot(x = 'value', y ='rating', data = combined_data_violin_plot);
violin_plot.set_xticklabels(['Offense\n Player 1','Offense\n Player 2','Offense\n Player 3','Offense\n Player 4','Offense\n Player 5',
                            'Defense\n Player 1','Defense\n Player 2','Defense\n Player 3','Defense\n Player 4','Defense\n Player 5'])
violin_plot.set_xlabel('Features')
violin_plot.set_ylabel('Points Per 100 Possession')
plt.savefig('violinplot.svg',bbox_inches="tight")
